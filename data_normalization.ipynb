# %%
# Dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# #### Genre

# %%
# Read superhero_cinema.csv as Pandas DataFrame
movie_df = pd.read_csv('Output/superhero_cinema.csv')

# %%
genre_split_df = movie_df.assign(Genre=movie_df['Genre'].str.split(','))
genre_split_df.head()
# Out:
#    Film ID                              Title  Year  Rated    Released  \
# 0        0                            Ant-Man  2015  PG-13  2015-07-17
# 1        1               Ant-Man and the Wasp  2018  PG-13  2018-07-06
# 2        2  Ant-Man and the Wasp: Quantumania  2023  PG-13  2023-02-17
# 3        3                            Aquaman  2018  PG-13  2018-12-21
# 4        4            Avengers: Age of Ultron  2015  PG-13  2015-05-01
#
#    Runtime (min)                           Genre     Director  \
# 0            117      [Action,  Comedy,  Sci-Fi]  Peyton Reed
# 1            118   [Action,  Adventure,  Comedy]  Peyton Reed
# 2            124   [Action,  Adventure,  Comedy]  Peyton Reed
# 3            143  [Action,  Adventure,  Fantasy]    James Wan
# 4            141   [Action,  Adventure,  Sci-Fi]  Joss Whedon
#
#                                               Writer  \
# 0              Edgar Wright, Joe Cornish, Adam McKay
# 1             Chris McKenna, Erik Sommers, Paul Rudd
# ...

# %%
genre_explode_df = genre_split_df.explode('Genre').reset_index(drop=True)
genre_explode_df.head()
# Out:
#    Film ID                 Title  Year  Rated    Released  Runtime (min)  \
# 0        0               Ant-Man  2015  PG-13  2015-07-17            117
# 1        0               Ant-Man  2015  PG-13  2015-07-17            117
# 2        0               Ant-Man  2015  PG-13  2015-07-17            117
# 3        1  Ant-Man and the Wasp  2018  PG-13  2018-07-06            118
# 4        1  Ant-Man and the Wasp  2018  PG-13  2018-07-06            118
#
#         Genre     Director                                  Writer  \
# 0      Action  Peyton Reed   Edgar Wright, Joe Cornish, Adam McKay
# 1      Comedy  Peyton Reed   Edgar Wright, Joe Cornish, Adam McKay
# 2      Sci-Fi  Peyton Reed   Edgar Wright, Joe Cornish, Adam McKay
# 3      Action  Peyton Reed  Chris McKenna, Erik Sommers, Paul Rudd
# 4   Adventure  Peyton Reed  Chris McKenna, Erik Sommers, Paul Rudd
#
#                                       Actors  Rotten Tomatoes Rating (%)  \
# ...

# %%
# Create list of genres
genres = genre_explode_df['Genre'].unique()
len_genres = len(genres)
genre_ids = np.arange(1, len_genres + 1)
print(genres)
print(genre_ids)
# Out:
# ['Action' ' Comedy' ' Sci-Fi' ' Adventure' ' Fantasy' ' Drama' ' Crime']
# [1 2 3 4 5 6 7]

# %%
genre_id_df = pd.DataFrame({'Genre ID': genre_ids, 'Genre': genres})
genre_id_df
# Out:
#    Genre ID       Genre
# 0         1      Action
# 1         2      Comedy
# 2         3      Sci-Fi
# 3         4   Adventure
# 4         5     Fantasy
# 5         6       Drama
# 6         7       Crime

# %%
genre_mapping = genre_id_df.set_index('Genre')['Genre ID'].to_dict()
genre_mapping
# Out:
# {'Action': 1,
#  ' Comedy': 2,
#  ' Sci-Fi': 3,
#  ' Adventure': 4,
#  ' Fantasy': 5,
#  ' Drama': 6,
#  ' Crime': 7}

# %%
genre_explode_df['Genre ID'] = genre_explode_df['Genre'].map(genre_mapping)
genre_explode_df.head(10)
# Out:
#    Film ID                              Title  Year  Rated    Released  \
# 0        0                            Ant-Man  2015  PG-13  2015-07-17
# 1        0                            Ant-Man  2015  PG-13  2015-07-17
# 2        0                            Ant-Man  2015  PG-13  2015-07-17
# 3        1               Ant-Man and the Wasp  2018  PG-13  2018-07-06
# 4        1               Ant-Man and the Wasp  2018  PG-13  2018-07-06
# 5        1               Ant-Man and the Wasp  2018  PG-13  2018-07-06
# 6        2  Ant-Man and the Wasp: Quantumania  2023  PG-13  2023-02-17
# 7        2  Ant-Man and the Wasp: Quantumania  2023  PG-13  2023-02-17
# 8        2  Ant-Man and the Wasp: Quantumania  2023  PG-13  2023-02-17
# 9        3                            Aquaman  2018  PG-13  2018-12-21
#
#    Runtime (min)       Genre     Director  \
# 0            117      Action  Peyton Reed
# 1            117      Comedy  Peyton Reed
# 2            117      Sci-Fi  Peyton Reed
# ...

# %%
genre_relation_df = genre_explode_df[['Film ID', 'Genre ID']]
genre_relation_df.head()
# Out:
#    Film ID  Genre ID
# 0        0         1
# 1        0         2
# 2        0         3
# 3        1         1
# 4        1         4

# %%
genre_explode_df.columns
# Out:
# Index(['Film ID', 'Title', 'Year', 'Rated', 'Released', 'Runtime (min)',
#        'Genre', 'Director', 'Writer', 'Actors', 'Rotten Tomatoes Rating (%)',
#        'Metascore', 'IMDB Rating', 'Box Office ($)', 'Franchise', 'Genre ID'],
#       dtype='object')

# %%
updated_movie_df = genre_explode_df[['Film ID', 'Title', 'Year', 'Rated', 'Released', 'Runtime (min)',
                                     'Director', 'Writer', 'Actors', 'Rotten Tomatoes Rating (%)',
                                     'Metascore', 'IMDB Rating', 'Box Office ($)', 'Franchise']]
updated_movie_df.drop_duplicates(inplace=True)
# Out:
# C:\Users\jgorin\AppData\Local\Temp\ipykernel_15572\1441089286.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_movie_df.drop_duplicates(inplace=True)

# %%
updated_movie_df.to_csv('Output/superhero_no_genre.csv', index=False)
genre_id_df.to_csv('Output/genre.csv', index=False)
genre_relation_df.to_csv('Output/genre_relation.csv', index=False)

# %% [markdown]
# #### Director

# %%
# Read superhero_no_genre.csv
movie_df = pd.read_csv('Output/superhero_no_genre.csv')
